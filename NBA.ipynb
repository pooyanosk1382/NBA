# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import sympy as sp

# %% [markdown]
# __Opening File :__

# %%
df = pd.read_csv('nba_playoffs.csv')
df
# Out:
#     rank               player position  \
# 0      1         LeBron James    SF/PF
# 1      2       Michael Jordan    SG/SF
# 2      3  Kareem Abdul-Jabbar        C
# 3      4          Kobe Bryant    SG/SF
# 4      5     Shaquille O'Neal        C
# 5      6           Tim Duncan     PF/C
# 6      7          Karl Malone       PF
# 7      8         Kevin Durant       SF
# 8      9           Jerry West    PG/SG
# 9     10          Tony Parker       PG
# 10    11          Dwyane Wade       SG
# 11    12           Larry Bird    SF/PF
# 12    13        John Havlicek    SF/SG
# 13    14      Hakeem Olajuwon        C
# 14    15        Magic Johnson       PG
# 15    16        Dirk Nowitzki       PF
# 16    17       Scottie Pippen       SF
# 17    18         Elgin Baylor       SF
# 18    19     Wilt Chamberlain        C
# 19    20        Stephen Curry       PG
# 20    21         James Harden       SG
# 21    22         Kevin McHale       PF
# 22    23          Paul Pierce    SF/SG
# ...

# %% [markdown]
# __Counting the misses files :__

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n",
      df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  rank                     0
# player                   0
# position                 0
# teams                    0
# total_points             0
# total_games              0
# total_points_pre_game    0
# field_goals              0
# three_points_goals       0
# free_shots               0
# born                     0
# active_player            0
# hall_of_fame             7
# country                  0
# recording_year           0
# dtype: int64

# %% [markdown]
# __Start plotting :)__
# At first a bar plot that shows the relation of players and points.

# %%
df.plot(x="player", y="total_points", kind="bar")
# Out:
# <AxesSubplot: xlabel='player'>

# %% [markdown]
# Now a plot of players and their average points per game.

# %%
df.plot(x="player", y="total_points_pre_game", kind="bar")
# Out:
# <AxesSubplot: xlabel='player'>

# %%
df.plot(x="player", y="total_games", kind= "bar")
# Out:
# <AxesSubplot: xlabel='player'>
